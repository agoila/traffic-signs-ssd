# %%
PATH = 'aiua120214-0/frameAnnotations-DataLog02142012_external_camera.avi_annotations/'

# %%
# !ls {PATH}
# Out:
# diff.txt
# frameAnnotations.bak
# frameAnnotations.bak2
# frameAnnotations.csv
# keepRight_1330547092.avi_image10.png
# keepRight_1330547092.avi_image11.png
# keepRight_1330547092.avi_image12.png
# keepRight_1330547092.avi_image15.png
# keepRight_1330547092.avi_image16.png
# keepRight_1330547092.avi_image17.png
# keepRight_1330547092.avi_image18.png
# keepRight_1330547092.avi_image19.png
# keepRight_1330547092.avi_image1.png
# keepRight_1330547092.avi_image20.png
# keepRight_1330547092.avi_image21.png
# keepRight_1330547092.avi_image22.png
# keepRight_1330547092.avi_image23.png
# keepRight_1330547092.avi_image24.png
# keepRight_1330547092.avi_image25.png
# keepRight_1330547092.avi_image26.png
# keepRight_1330547092.avi_image27.png
# keepRight_1330547092.avi_image28.png
# keepRight_1330547092.avi_image2.png
# keepRight_1330547092.avi_image3.png
# keepRight_1330547092.avi_image4.png
# keepRight_1330547092.avi_image5.png
# keepRight_1330547092.avi_image6.png
# ...

# %%
import pandas as pd

# %%
frameAnnotations_df = pd.read_csv(f'{PATH}frameAnnotations.csv')

# %%
frameAnnotations_df.columns[0]
# Out:
# 'Filename;Annotation tag;Upper left corner X;Upper left corner Y;Lower right corner X;Lower right corner Y;Occluded'

# %%
import PIL
from PIL import Image

# %%
img = Image.open(f'{PATH}keepRight_1330547092.avi_image18.png')

# %%
import glob

# %%
def get_sizes():
    sz = [PIL.Image.open(f'{PATH}/{k.split("/")[-1]}').size for k in glob.glob(f'{PATH}*.png')]
    height = np.array([sz[i][0] for i in range(len(sz))])
    width = np.array([sz[i][1] for i in range(len(sz))])
    return height, width

# %%
import numpy as np

# %%
heights, widths = get_sizes()

# %%
frameAnnotations_df.head()
# Out:
#   Filename;Annotation tag;Upper left corner X;Upper left corner Y;Lower right corner X;Lower right corner Y;Occluded  \
# 0  stop_1330545910.avi_image0.png;stop;862;104;91...
# 1  stop_1330545910.avi_image0.png;speedLimitUrdbl...
# 2  stop_1330545910.avi_image1.png;stop;922;88;982...
# 3  stop_1330545910.avi_image1.png;speedLimit25;44...
# 4  stop_1330545910.avi_image2.png;speedLimit25;46...
#
#   On another road;Origin file;Origin frame number;Origin track;Origin track frame number
# 0  0;aiua120214-0/DataLog02142012_external_camera...
# 1  0;aiua120214-0/DataLog02142012_external_camera...
# 2  0;aiua120214-0/DataLog02142012_external_camera...
# 3  0;aiua120214-0/DataLog02142012_external_camera...
# 4  0;aiua120214-0/DataLog02142012_external_camera...

# %%
df = pd.DataFrame(columns=[*frameAnnotations_df.columns[0].split(';'), *frameAnnotations_df.columns[1].split(';')])

# %%
frameAnnotations_df[
    'Filename;Annotation tag;Upper left corner X;Upper left corner Y;Lower right corner X;Lower right corner Y;Occluded'][0]
# Out:
# 'stop_1330545910.avi_image0.png;stop;862;104;916;158;0'

# %%
frame_col_1 = frameAnnotations_df[
    'Filename;Annotation tag;Upper left corner X;Upper left corner Y;Lower right corner X;Lower right corner Y;Occluded']

# %%
vals = [frame_col_1[i].split(';') for i in range(len(frame_col_1))]

# %%
vals
# Out:
# [['stop_1330545910.avi_image0.png', 'stop', '862', '104', '916', '158', '0'],
#  ['stop_1330545910.avi_image0.png',
#   'speedLimitUrdbl',
#   '425',
#   '197',
#   '438',
#   '213',
#   '0'],
#  ['stop_1330545910.avi_image1.png', 'stop', '922', '88', '982', '148', '1'],
#  ['stop_1330545910.avi_image1.png',
#   'speedLimit25',
#   '447',
#   '193',
#   '461',
#   '210',
#   '0'],
#  ['stop_1330545910.avi_image2.png',
#   'speedLimit25',
#   '469',
#   '189',
#   '483',
#   '207',
#   '0'],
#  ['speedLimit_1330545914.avi_image0.png',
#   'speedLimit25',
#   '529',
#   '183',
#   '546',
#   '203',
#   '0'],
#  ['speedLimit_1330545914.avi_image1.png',
#   'speedLimit25',
#   '526',
#   '191',
#   '543',
#   '211',
#   '1'],
#  ['speedLimit_1330545914.avi_image2.png',
#   'speedLimit25',
#   '522',
#   '189',
#   '540',
#   '210',
#   '1'],
#  ['speedLimit_1330545914.avi_image3.png',
#   'speedLimit25',
#   '518',
#   '191',
#   '536',
#   '213',
#   '0'],
# ...

# %%
df.columns
# Out:
# Index(['Filename', 'Annotation tag', 'Upper left corner X',
#        'Upper left corner Y', 'Lower right corner X', 'Lower right corner Y',
#        'Occluded', 'On another road', 'Origin file', 'Origin frame number',
#        'Origin track', 'Origin track frame number'],
#       dtype='object')

# %%
df.Filename, df['Annotation tag'], df['Upper left corner X'], df['Upper left corner Y'], df['Lower right corner X'], df['Lower right corner Y'], df['Occluded'] = [[vals[i][j] for i in range(len(vals))] for j in range(7)]

# %%
df.head()
# Out:
#                          Filename   Annotation tag Upper left corner X  \
# 0  stop_1330545910.avi_image0.png             stop                 862
# 1  stop_1330545910.avi_image0.png  speedLimitUrdbl                 425
# 2  stop_1330545910.avi_image1.png             stop                 922
# 3  stop_1330545910.avi_image1.png     speedLimit25                 447
# 4  stop_1330545910.avi_image2.png     speedLimit25                 469
#
#   Upper left corner Y Lower right corner X Lower right corner Y Occluded  \
# 0                 104                  916                  158        0
# 1                 197                  438                  213        0
# 2                  88                  982                  148        1
# 3                 193                  461                  210        0
# 4                 189                  483                  207        0
#
#   On another road Origin file Origin frame number Origin track  \
# ...

# %%
frame_col_2 = frameAnnotations_df['On another road;Origin file;Origin frame number;Origin track;Origin track frame number']

# %%
vals2 = [frame_col_2[i].split(';') for i in range(len(frame_col_2))]

# %%
df['On another road'], df['Origin file'], df['Origin frame number'], df['Origin track'], df['Origin track frame number'] = [[vals2[i][j] for i in range(len(vals2))] for j in range(5)]

# %%
df.head()
# Out:
#                          Filename   Annotation tag Upper left corner X  \
# 0  stop_1330545910.avi_image0.png             stop                 862
# 1  stop_1330545910.avi_image0.png  speedLimitUrdbl                 425
# 2  stop_1330545910.avi_image1.png             stop                 922
# 3  stop_1330545910.avi_image1.png     speedLimit25                 447
# 4  stop_1330545910.avi_image2.png     speedLimit25                 469
#
#   Upper left corner Y Lower right corner X Lower right corner Y Occluded  \
# 0                 104                  916                  158        0
# 1                 197                  438                  213        0
# 2                  88                  982                  148        1
# 3                 193                  461                  210        0
# 4                 189                  483                  207        0
#
#   On another road                                       Origin file  \
# ...

# %%
df.to_csv('aiua120214-0-summary.csv', index=False)

# %%
# !ln -s ../fastai/fastai/ ./

# %%
from fastai.imports import *

# %%
FileLink('aiua120214-0-summary.csv')
# Out:
# /home/nbuser/traffic-ssd-keras/aiua120214-0-summary.csv

# %%
csv_file = pd.read_csv('allAnnotations.csv')

# %%
csv_file.head()
# Out:
#   Filename;Annotation tag;Upper left corner X;Upper left corner Y;Lower right corner X;Lower right corner Y;Occluded  \
# 0  aiua120214-0/frameAnnotations-DataLog02142012_...
# 1  aiua120214-0/frameAnnotations-DataLog02142012_...
# 2  aiua120214-0/frameAnnotations-DataLog02142012_...
# 3  aiua120214-0/frameAnnotations-DataLog02142012_...
# 4  aiua120214-0/frameAnnotations-DataLog02142012_...
#
#   On another road;Origin file;Origin frame number;Origin track;Origin track frame number
# 0  0;aiua120214-0/DataLog02142012_external_camera...
# 1  0;aiua120214-0/DataLog02142012_external_camera...
# 2  0;aiua120214-0/DataLog02142012_external_camera...
# 3  0;aiua120214-0/DataLog02142012_external_camera...
# 4  0;aiua120214-0/DataLog02142012_external_camera...

# %%
frame_col_1 = csv_file[
    'Filename;Annotation tag;Upper left corner X;Upper left corner Y;Lower right corner X;Lower right corner Y;Occluded']

# %%
vals = [frame_col_1[i].split(';') for i in range(len(frame_col_1))]

# %%
df = pd.DataFrame(columns=[*csv_file.columns[0].split(';'), *csv_file.columns[1].split(';')])

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Filename, Annotation tag, Upper left corner X, Upper left corner Y, Lower right corner X, Lower right corner Y, Occluded, On another road, Origin file, Origin frame number, Origin track, Origin track frame number]
# Index: []

# %%
df.Filename, df['Annotation tag'], df['Upper left corner X'], df['Upper left corner Y'], df['Lower right corner X'], df['Lower right corner Y'], df['Occluded'] = [[vals[i][j] for i in range(len(vals))] for j in range(7)]

# %%
frame_col_2 = csv_file['On another road;Origin file;Origin frame number;Origin track;Origin track frame number']

# %%
vals2 = [frame_col_2[i].split(';') for i in range(len(frame_col_2))]

# %%
df['On another road'], df['Origin file'], df['Origin frame number'], df['Origin track'], df['Origin track frame number'] = [[vals2[i][j] for i in range(len(vals2))] for j in range(5)]

# %%
df.head()
# Out:
#                                             Filename   Annotation tag  \
# 0  aiua120214-0/frameAnnotations-DataLog02142012_...             stop
# 1  aiua120214-0/frameAnnotations-DataLog02142012_...  speedLimitUrdbl
# 2  aiua120214-0/frameAnnotations-DataLog02142012_...             stop
# 3  aiua120214-0/frameAnnotations-DataLog02142012_...     speedLimit25
# 4  aiua120214-0/frameAnnotations-DataLog02142012_...     speedLimit25
#
#   Upper left corner X Upper left corner Y Lower right corner X  \
# 0                 862                 104                  916
# 1                 425                 197                  438
# 2                 922                  88                  982
# 3                 447                 193                  461
# 4                 469                 189                  483
#
#   Lower right corner Y Occluded On another road  \
# 0                  158        0               0
# 1                  213        0               0
# ...

# %%
df.to_csv('allAnnotations-summary.csv', index=False)

# %%
FileLink('allAnnotations-summary.csv')
# Out:
# /home/nbuser/traffic-ssd-keras/allAnnotations-summary.csv
